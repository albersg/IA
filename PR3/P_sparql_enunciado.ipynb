# %% [markdown]
# # Práctica 3: Representación del conocimiento
#
# __Fecha de entrega: 5 de junio de 2022__
#
# El objetivo de esta práctica es aplicar los conceptos teóricos vistos en clase en el módulo de Representación de conocimiento. La práctica consta de un único notebook que se entregará en la tarea de entrega habilitada en el Campus  Virtual.
#
# Cada consulta debe contener breves comentarios que expliquen cada tripleta. __No se valorarán consultas sin explicaciones__.

# %% [markdown]
# __Número de grupo: 19__
#
# __Nombres de los estudiantes: SÁNCHEZ GÓMEZ, ALBERTO y CARPIO CUENCA, SARA__

# %% [markdown]
# ## Consultas SPARQL sobre Wikidata.
#
# En esta práctica vamos a usar el [punto de acceso SPARQL](https://query.wikidata.org/) de Wikidata para contestar las preguntas que se formulan a continuación. Cada pregunta debe ser respondida realizando una única consulta SPARQL. Para cada una de las entidades recuperadas se mostrará __tanto su identificador como su etiqueta__ (nombre de la entidad en lenguaje natural).
#
# Para cada una de las preguntas debes mostrar tanto la consulta como la respuesta obtenida. Si lo consideras necesario, puedes añadir celdas adicionales en formato _Markdown_ para explicar decisiones que hayas tomado al crear la consulta o cualquier otro dato que consideres interesante.
#
# Para resolver estas consultas puedes usar __dos recursos que te recomendamos consultar__ son:
#
# - [Este tutorial de SPARQL](https://www.wikidata.org/wiki/Wikidata:SPARQL_tutorial).
# - [Esta recopilación de ejemplos](https://www.wikidata.org/wiki/Wikidata:SPARQL_query_service/queries/examples)

# %%
## Lo primero sería instalar en tu entorno de Python wdsparql
## Si no lo tienes instalado, puedes hacerlo desde el notebook
import sys

# !{sys.executable} -m pip install wdsparql
# Out:
# Requirement already satisfied: wdsparql in c:\users\scc_1\appdata\python\python38-32\lib\site-packages (0.0.3)
# Requirement already satisfied: requests>=2.20 in c:\users\scc_1\appdata\python\python38-32\lib\site-packages (from wdsparql) (2.27.1)
# Requirement already satisfied: ipython>=7.0.0 in c:\users\scc_1\appdata\python\python38-32\lib\site-packages (from wdsparql) (7.27.0)
# Requirement already satisfied: pandas>=1.1 in c:\users\scc_1\appdata\python\python38-32\lib\site-packages (from wdsparql) (1.4.1)
# Requirement already satisfied: colorama in c:\users\scc_1\appdata\python\python38-32\lib\site-packages (from ipython>=7.0.0->wdsparql) (0.4.4)
# Requirement already satisfied: setuptools>=18.5 in c:\users\scc_1\appdata\python\python38-32\lib\site-packages (from ipython>=7.0.0->wdsparql) (41.2.0)
# Requirement already satisfied: pygments in c:\users\scc_1\appdata\python\python38-32\lib\site-packages (from ipython>=7.0.0->wdsparql) (2.10.0)
# Requirement already satisfied: traitlets>=4.2 in c:\users\scc_1\appdata\python\python38-32\lib\site-packages (from ipython>=7.0.0->wdsparql) (5.1.0)
# Requirement already satisfied: pickleshare in c:\users\scc_1\appdata\python\python38-32\lib\site-packages (from ipython>=7.0.0->wdsparql) (0.7.5)
# Requirement already satisfied: matplotlib-inline in c:\users\scc_1\appdata\python\python38-32\lib\site-packages (from ipython>=7.0.0->wdsparql) (0.1.3)
# Requirement already satisfied: decorator in c:\users\scc_1\appdata\python\python38-32\lib\site-packages (from ipython>=7.0.0->wdsparql) (5.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\scc_1\appdata\python\python38-32\lib\site-packages (from ipython>=7.0.0->wdsparql) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in c:\users\scc_1\appdata\python\python38-32\lib\site-packages (from ipython>=7.0.0->wdsparql) (0.18.0)
# Requirement already satisfied: backcall in c:\users\scc_1\appdata\python\python38-32\lib\site-packages (from ipython>=7.0.0->wdsparql) (0.2.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\scc_1\appdata\python\python38-32\lib\site-packages (from pandas>=1.1->wdsparql) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\scc_1\appdata\python\python38-32\lib\site-packages (from pandas>=1.1->wdsparql) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\scc_1\appdata\python\python38-32\lib\site-packages (from pandas>=1.1->wdsparql) (1.21.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\scc_1\appdata\python\python38-32\lib\site-packages (from requests>=2.20->wdsparql) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\scc_1\appdata\python\python38-32\lib\site-packages (from requests>=2.20->wdsparql) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\scc_1\appdata\python\python38-32\lib\site-packages (from requests>=2.20->wdsparql) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\scc_1\appdata\python\python38-32\lib\site-packages (from requests>=2.20->wdsparql) (2.0.12)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\scc_1\appdata\python\python38-32\lib\site-packages (from jedi>=0.16->ipython>=7.0.0->wdsparql) (0.8.2)
# Requirement already satisfied: wcwidth in c:\users\scc_1\appdata\python\python38-32\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.0.0->wdsparql) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\scc_1\appdata\python\python38-32\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.1->wdsparql) (1.16.0)

# %%
# Asumismos instalado wdsparql
# %load_ext autoreload
# %load_ext wdsparql
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The wdsparql extension is already loaded. To reload it, use:
#   %reload_ext wdsparql

# %% [markdown]
# ### Ejemplo
#
# Recuperar todas las instancias directas de la clase [Cabra (Q2934)](https://www.wikidata.org/wiki/Q2934) que aparecen en la base de conocimiento.

# %%
# %%wdsparql
# SELECT ?item ?itemLabel
# WHERE
# {
#   ?item wdt:P31 wd:Q2934.  # instancias directas de la clase Cabra
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
# }
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>item</th>
#       <th>itemLabel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><a href="http://www.wikidata.org/entity/Q151345" target="_blank">http://www.wikidata.org/entity/Q151345</a></td>
#       <td>Billygoat Hennes</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><a href="http://www.wikidata.org/entity/Q3569037" target="_blank">http://www.wikidata.org/entity/Q3569037</a></td>
#       <td>William Windsor</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><a href="http://www.wikidata.org/entity/Q23003932" target="_blank">http://www.wikidata.org/entity/Q23003932</a></td>
#       <td>His Whiskers</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><a href="http://www.wikidata.org/entity/Q24287064" target="_blank">http://www.wikidata.org/entity/Q24287064</a></td>
#       <td>Taffy</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><a href="http://www.wikidata.org/entity/Q41239734" target="_blank">http://www.wikidata.org/entity/Q41239734</a></td>
#       <td>Lance Corporal Shenkin III</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><a href="http://www.wikidata.org/entity/Q41240892" target="_blank">http://www.wikidata.org/entity/Q41240892</a></td>
#       <td>Lance Corporal Shenkin II</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><a href="http://www.wikidata.org/entity/Q41241416" target="_blank">http://www.wikidata.org/entity/Q41241416</a></td>
#       <td>Lance Corporal Shenkin I</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Consulta 1
#
# [Isaac Asimov (Q34981)](https://www.wikidata.org/wiki/Q34981) fue un escritor y profesor de bioquímica en la Universidad de Boston conocido por ser un prolífico autor de obras de ciencia ficción, historia y divulgación científica.
#
# Vamos a comenzar por averiguar su fecha y lugar de nacimiento (localidad y país al que pertenece la localidad en la actualidad).

# %%
# %%wdsparql
# SELECT ?fecha ?localidadLabel ?paisLabel
# WHERE {
#   wd:Q34981 wdt:P569 ?fecha; # obtenemos la fecha
#             wdt:P19 ?localidad. # obtenemos localidad
#   ?localidad wdt:P17 ?pais. # obtenemos el pais correspondiente a la localidad obtenida
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
# }
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>fecha</th>
#       <th>localidadLabel</th>
#       <th>paisLabel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1920-01-02T00:00:00Z</td>
#       <td>Petrovichi</td>
#       <td>Russia</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Hemos usado primero la propiedad "fecha de nacimiento" para obtener la fecha y la propiedad "lugar de nacimiento" para obtener la localidad. Luego hemos obtenido el país al que pertenece la localidad obtenida con la propiedad "país".

# %% [markdown]
# ### Consulta 2
#
# A continuación vamos a averiguar todas las distintas profesiones (ocupaciones) que se le reconocen en la base de conocimiento. Queremos obtener los resultados ordenados alfabéticamente por el nombre de la profesión.

# %%
# %%wdsparql
# SELECT ?ocupacionLabel
# WHERE {
#   wd:Q34981 wdt:P106 ?ocupacion. # obtenemos ocupaciones de Asimov
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
# }
# ORDER BY ASC(?ocupacionLabel)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ocupacionLabel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>autobiographer</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>biochemist</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>journalist</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>non-fiction writer</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>novelist</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>prosaist</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>science fiction writer</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>science writer</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>scientist</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>screenwriter</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>university teacher</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>writer</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Hemos usado la propiedad "ocupación" para obtener todas sus profesiones y luego las hemos ordenado de forma ascendente con ORDER BY, usando la ocupacionLabel.

# %% [markdown]
# ### Consulta 3
#
# De todas esas profesiones, ¿cuáles corresponden con subtipos de [Escritor (Q36180)](https://www.wikidata.org/wiki/Q36180)? Ten en cuenta que la jerarquía de tipos de escritores puede ser muy sofisticada.
#
# Puede que [esto](https://www.wikidata.org/wiki/Wikidata:SPARQL_tutorial#Property_paths) te resulte útil.

# %%
# %%wdsparql
# SELECT ?ocupacionLabel
# WHERE {
#   wd:Q34981 wdt:P106 ?ocupacion. # obtenemos las ocupaciones
#   ?ocupacion wdt:P279* wd:Q36180. # nos quedamos con las que pertenecen a subclases de Escritor
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
# }
# ORDER BY ASC(?ocupacionLabel)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ocupacionLabel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>autobiographer</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>biochemist</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>journalist</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>non-fiction writer</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>novelist</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>prosaist</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>science fiction writer</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>science writer</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>scientist</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>screenwriter</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>university teacher</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>writer</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# %%wdsparql
# SELECT ?ocupacionLabel
# WHERE {
#   wd:Q34981 wdt:P106 ?ocupacion.
#   ?ocupacion wdt:P279 wd:Q36180.
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
# }
# ORDER BY ASC(?ocupacionLabel)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ocupacionLabel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>journalist</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>non-fiction writer</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>novelist</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>prosaist</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>science writer</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>screenwriter</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Vemos que hijos directos de la clase `Escritor` solo son 6 (que son los de la segunda consulta). En cambio, si miramos la jerarquía completa de descendencia, vemos que todas sus profesiones son subclases de `Escritor`.

# %% [markdown]
# ### Consulta 4
#
# Asimov se casó más de una vez. Para cada uno de los matrimonios queremos conocer el nombre de la esposa y las fechas de inicio y finalización. Los resultados deben aparecer ordenados cronológicamente.
#
# Para resolver esta consulta necesitarás acceder a los cualificadores de nodos sentencia y necesitarás entender los prefijos que usa Wikidata. Puede que [esto](https://www.wikidata.org/wiki/Wikidata:SPARQL_tutorial#Qualifiers) te resulte útil.

# %%
# %%wdsparql
# SELECT ?esposaLabel ?fechaInicio ?fechaFinal
# WHERE
# {
#   wd:Q34981 p:P26 [ps:P26 ?esposa;
#                    pq:P580 ?fechaInicio;
#                    pq:P582 ?fechaFinal].
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". } # Helps get the label in your language, if not, then en language
# }
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>esposaLabel</th>
#       <th>fechaInicio</th>
#       <th>fechaFinal</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Gertrude Asimov</td>
#       <td>1942-07-26T00:00:00Z</td>
#       <td>1973-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Janet Asimov</td>
#       <td>1973-01-01T00:00:00Z</td>
#       <td>1992-01-01T00:00:00Z</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Tenemos que acceder al nodo de información sobre los matrimonios de Asimov. Para ello, usamos el prefijo "p". Una vez dentro del nodo, accedemos al nombre de su esposa con el prefijo "ps".
# Para saber la información sobre las fechas, accedemos a estos campos con el prefijo "pq".

# %% [markdown]
# ### Consulta 5
#
# Asimov recibió muchos premios a lo largo de su carrera. Queremos obtener la lista de premios y, para cada uno de ellos, la fecha y la obra por la que fue premiado (si están disponibles). Los resultados se deben mostrar ordenador por fecha.
#
# Puede que [esto](https://www.wikidata.org/wiki/Wikidata:SPARQL_tutorial#OPTIONAL) te resulte útil.

# %%
# %%wdsparql
# SELECT ?premioLabel ?fecha ?obraLabel
# WHERE
# {
#   wd:Q34981 p:P166 ?statement.
#   ?statement ps:P166 ?premio.
#   OPTIONAL {?statement pq:P585 ?fecha.}
#   OPTIONAL {?statement pq:P1686 ?obra.}
#
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". } # Helps get the label in your language, if not, then en language
# }
# ORDER BY (?fecha)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>premioLabel</th>
#       <th>fecha</th>
#       <th>obraLabel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Fellow of the Committee for Skeptical Inquiry</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>AAAS Fellow</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Hugo Award</td>
#       <td>1963-01-01T00:00:00Z</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>James T. Grady-James H. Stack Award for Interp...</td>
#       <td>1965-01-01T00:00:00Z</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Hugo Award</td>
#       <td>1966-01-01T00:00:00Z</td>
#       <td>Foundation Trilogy</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Edward E. Smith Memorial Award</td>
#       <td>1967-01-01T00:00:00Z</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Nebula Award for Best Novel</td>
#       <td>1972-01-01T00:00:00Z</td>
#       <td>The Gods Themselves</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Hugo Award for Best Novel</td>
#       <td>1973-01-01T00:00:00Z</td>
#       <td>The Gods Themselves</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Locus Award for Best Novel</td>
#       <td>1973-01-01T00:00:00Z</td>
#       <td>The Gods Themselves</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Klumpke-Roberts Award</td>
#       <td>1975-01-01T00:00:00Z</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Nebula Award for Best Novelette</td>
#       <td>1976-01-01T00:00:00Z</td>
#       <td>The Bicentennial Man</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Hugo Award for Best Novelette</td>
#       <td>1977-01-01T00:00:00Z</td>
#       <td>The Bicentennial Man</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Locus Award for Best Novelette</td>
#       <td>1977-01-01T00:00:00Z</td>
#       <td>The Bicentennial Man</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Locus Award for Best Science Fiction Novel</td>
#       <td>1983-01-01T00:00:00Z</td>
#       <td>Foundation’s Edge</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Hugo Award for Best Novel</td>
#       <td>1983-01-01T00:00:00Z</td>
#       <td>Foundation’s Edge</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Humanist of the Year</td>
#       <td>1984-01-01T00:00:00Z</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Cosmos 2000 Award</td>
#       <td>1985-01-01T00:00:00Z</td>
#       <td>The Robots of Dawn</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Locus Award for Best Short Story</td>
#       <td>1987-01-01T00:00:00Z</td>
#       <td>Robot Dreams</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Damon Knight Memorial Grand Master Award</td>
#       <td>1987-01-01T00:00:00Z</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Hugo Award for Best Novelette</td>
#       <td>1992-01-01T00:00:00Z</td>
#       <td>Gold</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Hugo Award for Best Related Work</td>
#       <td>1995-01-01T00:00:00Z</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Retro Hugo Award</td>
#       <td>1996-01-01T00:00:00Z</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Science Fiction and Fantasy Hall of Fame</td>
#       <td>1997-01-01T00:00:00Z</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Usamos la misma idea que en la anterior consulta, solo que ahora tenemos que hacer el uso del OPTIONAL.
# Tenemos que usarlo para cada una de las tripletas relacionadas con la fecha y la obra, ya que si lo ponemos todas juntas nos devuelve solamente los premios donde los dos campos están disponibles.
# Para las consultas donde el campo no esta disponible no se muestra nada.

# %% [markdown]
# ### Consulta 6
#
# Ahora queremos conocer todas las obras escritas por Asimov del tipo [obras literarias de ciencia ficción (Q3238422)](https://www.wikidata.org/wiki/Q3238422) y cualquiera de sus subgéneros. Los resultados se deben mostrar ordenados por nombre.
#
# No pasa nada si en el resultado aparecen mezclados novelas, relatos, colecciones...

# %%
# %%wdsparql
# SELECT ?obraLabel
# WHERE
# {
#   ?obra wdt:P50 wd:Q34981;
#         wdt:P136 [wdt:P279* wd:Q3238422].
#
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". } # Helps get the label in your language, if not, then en language
# }
# ORDER BY ?obraLabel
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>obraLabel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>. . . That Thou Art Mindful of Him</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2430 A. D.</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>A Loint of Paw</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>A Statue for Father</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Anniversary</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Author! Author!</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Black Friar of the Flame</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Blank!</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Blind Alley</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Breeds There a Man...?</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Button, Button</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Buy Jupiter</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>C-Chute</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Cal</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Catch That Rabbit</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Christmas on Ganymede</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Darwinian Pool Room</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Day of the Hunters</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Death Sentence</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Die Rettung des Imperiums</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Dreaming Is a Private Thing</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Each an Explorer</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Everest</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Evidence</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>Exile to Hell</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>Eyes Do More Than See</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>First Law</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>Flies</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>For the Birds</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>Forward the Foundation</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>Foundation Trilogy</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>Foundation series</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>Founding Father</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>Franchise</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>Galley Slave</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>Good Taste</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>Green Patches</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>Half-Breeds on Venus</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>Hallucination</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>Heredity</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>History</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>Homo Sol</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>I'm in Marsport Without Hilda</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>I, Robot</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>In a Good Cause—</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>Insert Knob A In Hole B</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>It's Such a Beautiful Day</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>Left to Right</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>Lenny</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>Lest We Remember</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>Let's Get Together</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>Let's Not</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>Light Verse</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>Little Lost Robot</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>Lucky Starr and the Big Sun of Mercury</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>Lucky Starr and the Moons of Jupiter</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>Lucky Starr and the Pirates of the Asteroids</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>Lucky Starr and the Rings of Saturn</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>Lucky Starr series</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>Marching In</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>Marooned off Vesta</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>Mirror Image</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>Mother Earth</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>Nemesis</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>Nightfall</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>No Connection</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>Nobody Here But—</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>Obituary</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>Old-fashioned</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>Prelude to Foundation</td>
#     </tr>
#     <tr>
#       <th>70</th>
#       <td>Pâté de Foie Gras</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td>Rain, Rain, Go Away</td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td>Reason</td>
#     </tr>
#     <tr>
#       <th>73</th>
#       <td>Ring Around the Sun</td>
#     </tr>
#     <tr>
#       <th>74</th>
#       <td>Risk</td>
#     </tr>
#     <tr>
#       <th>75</th>
#       <td>Robbie</td>
#     </tr>
#     <tr>
#       <th>76</th>
#       <td>Robot AL-76 Goes Astray</td>
#     </tr>
#     <tr>
#       <th>77</th>
#       <td>Runaround</td>
#     </tr>
#     <tr>
#       <th>78</th>
#       <td>Satisfaction Guaranteed</td>
#     </tr>
#     <tr>
#       <th>79</th>
#       <td>Shah Guido G.</td>
#     </tr>
#     <tr>
#       <th>80</th>
#       <td>Spell My Name with an S</td>
#     </tr>
#     <tr>
#       <th>81</th>
#       <td>Star Light</td>
#     </tr>
#     <tr>
#       <th>82</th>
#       <td>Strikebreaker</td>
#     </tr>
#     <tr>
#       <th>83</th>
#       <td>Sucker Bait</td>
#     </tr>
#     <tr>
#       <th>84</th>
#       <td>Super-Neutron</td>
#     </tr>
#     <tr>
#       <th>85</th>
#       <td>Take a Match</td>
#     </tr>
#     <tr>
#       <th>86</th>
#       <td>The Billiard Ball</td>
#     </tr>
#     <tr>
#       <th>87</th>
#       <td>The Callistan Menace</td>
#     </tr>
#     <tr>
#       <th>88</th>
#       <td>The Complete Robot</td>
#     </tr>
#     <tr>
#       <th>89</th>
#       <td>The Currents of Space</td>
#     </tr>
#     <tr>
#       <th>90</th>
#       <td>The Dust of Death</td>
#     </tr>
#     <tr>
#       <th>91</th>
#       <td>The Dying Night</td>
#     </tr>
#     <tr>
#       <th>92</th>
#       <td>The Endochronic Properties of Resublimated Thi...</td>
#     </tr>
#     <tr>
#       <th>93</th>
#       <td>The Evitable Conflict</td>
#     </tr>
#     <tr>
#       <th>94</th>
#       <td>The Feeling of Power</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>The Gentle Vultures</td>
#     </tr>
#     <tr>
#       <th>96</th>
#       <td>The Greatest Asset</td>
#     </tr>
#     <tr>
#       <th>97</th>
#       <td>The Hazing</td>
#     </tr>
#     <tr>
#       <th>98</th>
#       <td>The Imaginary</td>
#     </tr>
#     <tr>
#       <th>99</th>
#       <td>The Immortal Bard</td>
#     </tr>
#     <tr>
#       <th>100</th>
#       <td>The Key</td>
#     </tr>
#     <tr>
#       <th>101</th>
#       <td>The Last Answer</td>
#     </tr>
#     <tr>
#       <th>102</th>
#       <td>The Last Question</td>
#     </tr>
#     <tr>
#       <th>103</th>
#       <td>The Magnificent Possession</td>
#     </tr>
#     <tr>
#       <th>104</th>
#       <td>The Monkey's Finger</td>
#     </tr>
#     <tr>
#       <th>105</th>
#       <td>The Pause</td>
#     </tr>
#     <tr>
#       <th>106</th>
#       <td>The Proper Study</td>
#     </tr>
#     <tr>
#       <th>107</th>
#       <td>The Red Queen's Race</td>
#     </tr>
#     <tr>
#       <th>108</th>
#       <td>The Secret Sense</td>
#     </tr>
#     <tr>
#       <th>109</th>
#       <td>The Singing Bell</td>
#     </tr>
#     <tr>
#       <

# %% [markdown]
# Lo primero que hacemos es obtener todas las obras escritas por Asimov. Una vez que las tenemos, nos quedamos solamente con las que su género coincide con alguno de los subgéneros de "obras literarias de ciencia ficción". Estos subgéneros los generamos como variables anónimas en la parte entre "[ ]"

# %% [markdown]
# ### Consulta 7
#
# Vamos a volver a recuperar las mismas obras de la consulta anterior pero mostrando también la fecha de publicación de cada una. Las obras deben aparece aunque no tengan fecha de publicación asociada. En caso de que una obra tenga varias fechas de publicación, se mostrará sólo la más antigua. Los resultados deben aparecer en orden cronológico.
#
# Para calcular la fecha correcta tendrás que agrupar las respuestas por obra y aplicar una función de agregación sobre las fechas de publicación. Puede que [esto](https://www.wikidata.org/wiki/Wikidata:SPARQL_tutorial#Grouping) te resulte útil.

# %%
# %%wdsparql
# SELECT ?obraLabel (MIN(?fecha) AS ?primeraFecha)
# WHERE
# {
#   ?obra wdt:P50 wd:Q34981;
#         wdt:P136 [wdt:P279* wd:Q3238422].
#   OPTIONAL {?obra wdt:P577 ?fecha}.
#
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". } # Helps get the label in your language, if not, then en language
# }
# GROUP BY ?obraLabel
# ORDER BY ?primeraFecha
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>obraLabel</th>
#       <th>primeraFecha</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Lucky Starr series</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Foundation series</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Satisfaction Guaranteed</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Foundation Trilogy</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>The Weapon Too Dreadful to Use</td>
#       <td>1939-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Trends</td>
#       <td>1939-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Marooned off Vesta</td>
#       <td>1939-03-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Half-Breeds on Venus</td>
#       <td>1940-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Ring Around the Sun</td>
#       <td>1940-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>The Callistan Menace</td>
#       <td>1940-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>The Magnificent Possession</td>
#       <td>1940-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Robbie</td>
#       <td>1940-09-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Homo Sol</td>
#       <td>1940-09-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Nightfall</td>
#       <td>1941-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Heredity</td>
#       <td>1941-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Super-Neutron</td>
#       <td>1941-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>History</td>
#       <td>1941-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>The Secret Sense</td>
#       <td>1941-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Reason</td>
#       <td>1941-04-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Victory Unintentional</td>
#       <td>1942-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Time Pussy</td>
#       <td>1942-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Robot AL-76 Goes Astray</td>
#       <td>1942-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>The Hazing</td>
#       <td>1942-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Christmas on Ganymede</td>
#       <td>1942-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>The Imaginary</td>
#       <td>1942-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>Black Friar of the Flame</td>
#       <td>1942-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>Runaround</td>
#       <td>1942-03-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>Death Sentence</td>
#       <td>1943-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>Catch That Rabbit</td>
#       <td>1944-02-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>Blind Alley</td>
#       <td>1945-03-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>Evidence</td>
#       <td>1946-09-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>Little Lost Robot</td>
#       <td>1947-03-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>The Endochronic Properties of Resublimated Thi...</td>
#       <td>1948-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>No Connection</td>
#       <td>1948-06-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>Mother Earth</td>
#       <td>1949-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>The Red Queen's Race</td>
#       <td>1949-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>Green Patches</td>
#       <td>1950-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>Darwinian Pool Room</td>
#       <td>1950-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>Day of the Hunters</td>
#       <td>1950-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>The Evitable Conflict</td>
#       <td>1950-06-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>I, Robot</td>
#       <td>1950-12-02T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>Breeds There a Man...?</td>
#       <td>1951-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>C-Chute</td>
#       <td>1951-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>In a Good Cause—</td>
#       <td>1951-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>Shah Guido G.</td>
#       <td>1951-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>The Currents of Space</td>
#       <td>1952-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>What If—</td>
#       <td>1952-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>Button, Button</td>
#       <td>1953-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>Everest</td>
#       <td>1953-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>Flies</td>
#       <td>1953-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>Nobody Here But—</td>
#       <td>1953-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>The Monkey's Finger</td>
#       <td>1953-02-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>Lucky Starr and the Pirates of the Asteroids</td>
#       <td>1953-11-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>Sucker Bait</td>
#       <td>1954-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>Lucky Starr and the Moons of Jupiter</td>
#       <td>1954-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>The Immortal Bard</td>
#       <td>1954-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>The Pause</td>
#       <td>1954-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>It's Such a Beautiful Day</td>
#       <td>1954-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>Let's Not</td>
#       <td>1954-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>Dreaming Is a Private Thing</td>
#       <td>1955-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>The Singing Bell</td>
#       <td>1955-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>The Talking Stone</td>
#       <td>1955-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>Risk</td>
#       <td>1955-05-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>Franchise</td>
#       <td>1955-08-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>First Law</td>
#       <td>1956-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>Each an Explorer</td>
#       <td>1956-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>Pâté de Foie Gras</td>
#       <td>1956-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>The Dying Night</td>
#       <td>1956-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>What's in a Name?</td>
#       <td>1956-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>Lucky Starr and the Big Sun of Mercury</td>
#       <td>1956-03-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>70</th>
#       <td>The Last Question</td>
#       <td>1956-11-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td>Galley Slave</td>
#       <td>1957-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td>I'm in Marsport Without Hilda</td>

# %% [markdown]
# Simplemente, usamos la consulta anterior, pero añadiendo la tripleta para calcular la fecha de publicación de cada obra (dentro de un bloque OPTIONAL por si acaso no dispone de este atributo).
# Como cada obra puede estar publicada en diferentes fechas, las agrupamos por su nombre solamente, y nos quedamos con la mínima (la primera) con una función de agregación MIN.
# Por último lo ordenamos por fecha para que salga con orden cronológico.

# %% [markdown]
# ### Consulta 8
#
# Asimov es sin duda un autor prolífico. ¿Cuántas obras escribió a lo largo de su vida? Vamos a considerar sólo instancias directas de [literary work (Q7725634)](https://www.wikidata.org/wiki/Q7725634).

# %%
# %%wdsparql
# SELECT (COUNT(?obra) AS ?count)
# WHERE
# {
#   ?obra wdt:P50 wd:Q34981;
#         wdt:P31 wd:Q7725634.
# }
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>272</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Seleccionamos las obras que tengan por autor a Asimov y que sean instancias de obra literaria. Con la función de agregación COUNT, hacemos el conteo.

# %% [markdown]
# ### Consulta 9
#
# De todas las obras que escribió a lo largo de su vida, queremos recuperar los nombres y fechas de publicación de aquellas escritas entre 1970 y 1980. Si alguna obra tiene varias fechas de publicación, se mostrará si alguna de ellas está dentro de ese periodo.
#
# Puede que [esto](https://www.wikidata.org/wiki/Wikidata:SPARQL_tutorial#FILTER) te resulte útil.

# %%
# %%wdsparql
# SELECT DISTINCT ?obraLabel ?fecha
# WHERE {
#   ?obra wdt:P50 wd:Q34981;
#         wdt:P577 ?fecha.
#   FILTER(("1970-01-01"^^xsd:dateTime <= ?fecha) && (?fecha < "1980-01-01"^^xsd:dateTime))
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE], en". }
# }
# ORDER BY (?fecha)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>obraLabel</th>
#       <th>fecha</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Waterclap</td>
#       <td>1970-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2430 A. D.</td>
#       <td>1970-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Asimov's Guide to Shakespeare</td>
#       <td>1970-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>The Solar System and Back</td>
#       <td>1970-01-19T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>As Chemist to Chemist</td>
#       <td>1970-05-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>The Stars in their Courses</td>
#       <td>1971-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>The Gods Themselves</td>
#       <td>1972-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Mirror Image</td>
#       <td>1972-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>The Early Asimov</td>
#       <td>1972-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Kid Stuff</td>
#       <td>1972-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Take a Match</td>
#       <td>1972-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>The Greatest Asset</td>
#       <td>1972-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>The Left Hand of the Electron</td>
#       <td>1972-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Q3345921</td>
#       <td>1972-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Q16652396</td>
#       <td>1972-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Q55172458</td>
#       <td>1972-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>asimov's guide to science</td>
#       <td>1972-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Light Verse</td>
#       <td>1973-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>The Tragedy of the Moon</td>
#       <td>1973-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Thiotimoline to the Stars</td>
#       <td>1973-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>The Best of Isaac Asimov</td>
#       <td>1973-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Androids, Time Machines and Blue Giraffes</td>
#       <td>1973-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Q104868766</td>
#       <td>1973-03-16T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Q104868864</td>
#       <td>1973-04-13T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>Q104868972</td>
#       <td>1973-05-11T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>Stranger in Paradise</td>
#       <td>1974-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>Tales of the Black Widowers</td>
#       <td>1974-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>Have You Seen These?</td>
#       <td>1974-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>Q98141420</td>
#       <td>1974-03-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>Before the Golden Age</td>
#       <td>1974-04-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>. . . That Thou Art Mindful of Him</td>
#       <td>1974-05-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>Q104865083</td>
#       <td>1974-06-18T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>Flug durch die Sonne</td>
#       <td>1974-07-16T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>Q104869051</td>
#       <td>1974-10-08T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>A Boy's Best Friend</td>
#       <td>1975-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>Point of View</td>
#       <td>1975-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>Lecherous Limericks</td>
#       <td>1975-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>Buy Jupiter and Other Stories</td>
#       <td>1975-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>Flûte, flûte et flûtes !</td>
#       <td>1975-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>The Life and Times of Multivac</td>
#       <td>1975-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>Of Matters Great and Small</td>
#       <td>1975-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>The Winnowing</td>
#       <td>1976-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>The Tercentenary Incident</td>
#       <td>1976-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>Good Taste</td>
#       <td>1976-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>Murder at the ABA</td>
#       <td>1976-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>Nightfall and Other Stories</td>
#       <td>1976-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>The Bicentennial Man and Other Stories</td>
#       <td>1976-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>More Tales of the Black Widowers</td>
#       <td>1976-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>Marching In</td>
#       <td>1976-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>Birth of a Notion</td>
#       <td>1976-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>Old-fashioned</td>
#       <td>1976-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>The Ultimate Crime</td>
#       <td>1976-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>The Planet That Wasn't</td>
#       <td>1976-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>The Bicentennial Man</td>
#       <td>1976-02-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>True Love</td>
#       <td>1977-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>Think!</td>
#       <td>1977-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>The Key Word and Other Mysteries</td>
#       <td>1977-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>The Collapsing Universe</td>
#       <td>1977-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>Sure Thing</td>
#       <td>1977-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>The Key Word</td>
#       <td>1977-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>Q98137394</td>
#       <td>1977-06-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>Q98446165</td>
#       <td>1977-08-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>Quasar, Quasar, Burning Bright</td>
#       <td>1978-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>The Science Fictional Solar System</td>
#       <td>1979-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>A Choice of Catastrophes</td>
#       <td>1979-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>Extraterrestrial Civilizations</td>
#       <td>1979-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>Isaac Asimov Presents The Great SF Stories 1</td>
#       <td>1979-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>The Road to Infinity</td>
#       <td>1979-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>Opus 200</td>
#       <td>1979-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>In Memory Yet Green</td>
#       <td>1979-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <

# %% [markdown]
# Recuperamos las obras escritas por Asimov y sus fechas de publicación. Con la clausula filter seleccionamos aquellas obras cuyas fechas de publicación estén entre 1970 y 1980. Con el modificador de búsqueda DISTINCT nos aseguramos de que cada obra salga una sola vez. Adicionalmente, las ordenamos por fecha para una mejor visualización.

# %% [markdown]
# ### Consulta 10
#
# ¿Qué otros escritores de ciencia ficción estudiaron en algún centro donde también estudió Asimov? Para cada uno de ellos muestra su nombre y fechas de nacimiento y defunción (si están disponibles) y el centro donde estudió. Muestra los resultados ordenados alfabéticamente por centro y luego por autor.

# %%
# %%wdsparql
# SELECT ?centroEducativoLabel ?autorLabel ?fechaNacimiento ?fechaMuerte
# WHERE {
#   wd:Q34981 wdt:P69 ?centroEducativo.
#   ?autor wdt:P106 wd:Q18844224;
#          wdt:P69 ?centroEducativo.
#   FILTER ( ?autor not in ( wd:Q34981 ) )
#   OPTIONAL {?autor wdt:P569 ?fechaNacimiento.}
#   OPTIONAL {?autor wdt:P570 ?fechaMuerte.}
#
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE], en". }
# }
# ORDER BY ?centroEducativoLabel ?autorLabel
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>centroEducativoLabel</th>
#       <th>autorLabel</th>
#       <th>fechaNacimiento</th>
#       <th>fechaMuerte</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Columbia University</td>
#       <td>Alaya Dawn Johnson</td>
#       <td>1982-03-31T00:00:00Z</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Columbia University</td>
#       <td>Algis Budrys</td>
#       <td>1931-01-09T00:00:00Z</td>
#       <td>2008-06-09T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Columbia University</td>
#       <td>Arthur W. Saha</td>
#       <td>1923-10-31T00:00:00Z</td>
#       <td>1999-11-19T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Columbia University</td>
#       <td>Ben Parris</td>
#       <td>1961-01-01T00:00:00Z</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Columbia University</td>
#       <td>David G. Hartwell</td>
#       <td>1941-07-10T00:00:00Z</td>
#       <td>2016-01-20T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Columbia University</td>
#       <td>David Kyle</td>
#       <td>1919-02-14T00:00:00Z</td>
#       <td>2016-09-18T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Columbia University</td>
#       <td>Donald Barr</td>
#       <td>1921-08-08T00:00:00Z</td>
#       <td>2004-02-05T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Columbia University</td>
#       <td>Doris Pitkin Buck</td>
#       <td>1898-01-03T00:00:00Z</td>
#       <td>1980-12-04T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Columbia University</td>
#       <td>Dorothy B. Hughes</td>
#       <td>1904-08-10T00:00:00Z</td>
#       <td>1993-05-06T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Columbia University</td>
#       <td>Eric Temple Bell</td>
#       <td>1883-02-07T00:00:00Z</td>
#       <td>1960-12-21T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Columbia University</td>
#       <td>Frank Belknap Long</td>
#       <td>1901-04-27T00:00:00Z</td>
#       <td>1994-01-03T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Columbia University</td>
#       <td>Gene Roddenberry</td>
#       <td>1921-08-19T00:00:00Z</td>
#       <td>1991-10-24T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Columbia University</td>
#       <td>Guy Endore</td>
#       <td>1900-07-04T00:00:00Z</td>
#       <td>1970-02-12T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Columbia University</td>
#       <td>Harvey Jacobs</td>
#       <td>1930-01-07T00:00:00Z</td>
#       <td>2017-09-23T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Columbia University</td>
#       <td>Harvey Jacobs</td>
#       <td>1930-01-07T00:00:00Z</td>
#       <td>2017-09-24T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Columbia University</td>
#       <td>Herbert Lieberman</td>
#       <td>1933-09-22T00:00:00Z</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Columbia University</td>
#       <td>Herman Wouk</td>
#       <td>1915-05-27T00:00:00Z</td>
#       <td>2019-05-17T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Columbia University</td>
#       <td>James Blish</td>
#       <td>1921-05-23T00:00:00Z</td>
#       <td>1975-07-30T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Columbia University</td>
#       <td>Jerry Robinson</td>
#       <td>1922-01-01T00:00:00Z</td>
#       <td>2011-12-07T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Columbia University</td>
#       <td>Jonathan Fast</td>
#       <td>1948-04-13T00:00:00Z</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Columbia University</td>
#       <td>Joseph McElroy</td>
#       <td>1930-08-21T00:00:00Z</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Columbia University</td>
#       <td>Kelly Link</td>
#       <td>1969-07-19T00:00:00Z</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Columbia University</td>
#       <td>Kira Peikoff</td>
#       <td>1985-05-21T00:00:00Z</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Columbia University</td>
#       <td>Leon Stover</td>
#       <td>1929-01-01T00:00:00Z</td>
#       <td>2006-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>Columbia University</td>
#       <td>Lin Carter</td>
#       <td>1930-06-09T00:00:00Z</td>
#       <td>1988-02-07T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>Columbia University</td>
#       <td>Lou Antonelli</td>
#       <td>1957-01-06T00:00:00Z</td>
#       <td>2021-10-06T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>Columbia University</td>
#       <td>Manly Wade Wellman</td>
#       <td>1903-05-21T00:00:00Z</td>
#       <td>1986-04-05T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>Columbia University</td>
#       <td>Mitch Berman</td>
#       <td>1956-05-29T00:00:00Z</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>Columbia University</td>
#       <td>Naomi Novik</td>
#       <td>1973-04-30T00:00:00Z</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>Columbia University</td>
#       <td>Peter Fisher</td>
#       <td>1944-05-19T00:00:00Z</td>
#       <td>2012-07-10T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>Columbia University</td>
#       <td>Peter Straub</td>
#       <td>1943-03-02T00:00:00Z</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>Columbia University</td>
#       <td>Rick Moody</td>
#       <td>1961-10-18T00:00:00Z</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>Columbia University</td>
#       <td>Robert Silverberg</td>
#       <td>1935-01-15T00:00:00Z</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>Columbia University</td>
#       <td>Robert Tine</td>
#       <td>1955-01-01T00:00:00Z</td>
#       <td>2019-02-22T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>Columbia University</td>
#       <td>Robin Cook</td>
#       <td>1940-05-04T00:00:00Z</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>Columbia University</td>
#       <td>Roger Zelazny</td>
#       <td>1937-05-13T00:00:00Z</td>
#       <td>1995-06-14T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>Columbia University</td>
#       <td>Sterling Noel</td>
#       <td>1903-03-28T00:00:00Z</td>
#       <td>1984-11-09T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>Columbia University</td>
#       <td>Thomas Berger</td>
#       <td>1924-07-20T00:00:00Z</td>
#       <td>2014-07-13T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>Columbia University</td>
#       <td>Ursula K. Le Guin</td>
#       <td>1929-10-21T00:00:00Z</td>
#       <td>2018-01-22T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>Columbia University</td>
#       <td>Victor LaValle</td>
#       <td>1972-02-03T00:00:00Z</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Primero, buscamos todos los centros educativos en los que estudió Asimov. Luego, buscamos a todos los autores de ciencia ficción que hayan estudiado en alguno de esos centros. Eliminamos a Asimov de la lista de autores con FILTER. Por último, buscamos las fechas de nacimiento y defunción de cada uno de los autores restante usando OPTIONAL, ya que es posible que falte alguna de las fechas.

# %% [markdown]
# ### Consulta 11
#
# ¿Cuántos asertos hay sobre Asimov en Wikidata? Ten en cuenta que Asimov puede aparece tanto como sujeto como objeto de cada tripleta.

# %%
# %%wdsparql
# SELECT ?suma
# WHERE
# {
#   {
#     SELECT (COUNT(?p1) AS ?count1)
#     WHERE{
#       wd:Q34981 ?p1 ?objeto.
#     }
#   }
#   {
#     SELECT (COUNT(?p2) AS ?count2)
#     WHERE{
#       ?subejto ?p2 wd:Q34981.
#     }
#   }
#     BIND(?count1 + ?count2 AS ?suma)
# }
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>suma</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2277</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Realizamos las dos consultas por separado y calculamos la suma.

# %% [markdown]
# __Fecha de las consultas: 21 de abril de 2022__

# %%
## Desinstalar wdsparql
import sys

# !{sys.executable} -m pip uninstall -y wdsparql
